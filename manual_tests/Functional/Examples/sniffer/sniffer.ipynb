# %%
from pyluos import Sniffer, Device
import time

# gate = Device('COM16')
sniffer = Sniffer('COM13')
# Out:
# Connected to "COM13".
# Device setup.

# %%
gate = Device('COM16')
# Out:
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "C:\Users\nicol\AppData\Local\Programs\Python\Python39\lib\threading.py", line 954, in _bootstrap_inner
#     self.run()
#   File "C:\Users\nicol\AppData\Local\Programs\Python\Python39\lib\threading.py", line 892, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\pyluos-1.5.0-py3.9.egg\pyluos\device.py", line 258, in _poll_and_up
#     state = self._poll_once()
#   File "C:\Users\nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\pyluos-1.5.0-py3.9.egg\pyluos\device.py", line 251, in _poll_once
#     self._state = self._io.read()
#   File "C:\Users\nicol\AppData\Local\Programs\Python\Python39\lib\site-packages\pyluos-1.5.0-py3.9.egg\pyluos\io\__init__.py", line 25, in read
#     return self.read(trials - 1)
# ...

# %%
gate.nodes

# %%
sniffer.stop

# %%
sniffer.start
time.sleep(1)
sniffer.pause
# Out:
# {'t':11340514392,'d':1,'s':8}0x1000310011010000
# {'t':11341519212,'d':1,'s':8}0x1000310011010000
# {'t':11342524452,'d':1,'s':8}0x1000310011010000
# {'t':11343570052,'d':1,'s':8}0x1000310011010000
# {'t':11344511932,'d':1,'s':8}0x1000310011010000
# {'t':11345516692,'d':1,'s':8}0x1000310011010000
# {'t':11346521452,'d':1,'s':8}0x1000310011010000
# {'t':11347567232,'d':1,'s':8}0x1000310011010000
# {'t':11348509132,'d':1,'s':8}0x1000310011010000
# {'t':11349513872,'d':1,'s':8}0x1000310011010000
# {'t':11350518832,'d':1,'s':8}0x1000310011010000
# {'t':11351564352,'d':1,'s':8}0x1000310011010000
# {'t':11352506372,'d':1,'s':8}0x1000310011010000
# {'t':11353511232,'d':1,'s':8}0x1000310011010000
# {'t':11354516112,'d':1,'s':8}0x1000310011010000
# {'t':11355499592,'d':1,'s':8}0x1000310011010000
# {'t':11356504112,'d':1,'s':8}0x1000310011010000
# {'t':11357508972,'d':1,'s':8}0x1000310011010000
# {'t':11358649092,'d':1,'s':8}0x1000310011010000
# {'t':11359557212,'d':1,'s':8}0x1000310011010000
# ...
